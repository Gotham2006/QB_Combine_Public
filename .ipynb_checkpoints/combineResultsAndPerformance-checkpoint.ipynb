# %%
import pandas as pd
combine2021 = pd.read_csv("2021Combine.csv")
combine2021
stats2021 = pd.read_csv("2021Stats.csv")
stats2021
# Out:
#     Unnamed: 0 Unnamed: 1 Unnamed: 2        Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0          Rnd       Pick         Tm            Player        Pos        Age
# 1            1          1        JAX   Trevor Lawrence         QB         21
# 2            1          2        NYJ       Zach Wilson         QB         22
# 3            1          3        SFO        Trey Lance         QB         21
# 4            1          4        ATL        Kyle Pitts         TE         20
# ..         ...        ...        ...               ...        ...        ...
# 255          7        255        NOR      Kawaan Baker         WR         23
# 256          7        256        GNB        Kylin Hill         RB         23
# 257          7        257        DET  Jermar Jefferson         RB         21
# 258          7        258        WAS         Dax Milne         WR         22
# 259          7        259        TAM      Grant Stuard         LB         22
#
# ...
