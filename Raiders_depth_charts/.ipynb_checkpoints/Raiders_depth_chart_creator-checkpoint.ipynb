# %%
data = {
    "Position": [
        "LWR", "RWR", "SWR", "LT", "LG", "C", "RG", "RT", "TE", "QB", "RB", "FB", "DE", "NT", "DT", "LOLB", "WLB", "MLB", "ROLB", "LCB", "SS", "FS", "RCB", "NB", "PT", "PK"],
    "Player 1": [
        "Bech, Jack", "Tucker, Tre", "Nailor, Jalen", "Miller, Kolton", "Burford, Spencer", 
        "Linderbaum, Tyler", "Powers-Johnson, Jackson", "Glaze, DJ", "Bowers, Brock", 
        "O'Connell, Aidan", "Jeanty, Ashton", "Heyward, Connor", "Wilson, Tyree", 
        "Butler, Adam", "Laulu, Jonah", "Paye, Kwity", "Walker, Quay", "Dean, Nakobe", 
        "Crosby, Maxx", "Stokes, Eric", "Chinn, Jeremy", "Pola-Mao, Isaiah", "Porter, Darien", 
        "Johnson, Taron", "Cole, AJ", "Gay, Matt"
    ],
    "Player 2": [
        "Thornton Jr., Dont'e", "Jackson, Shedrick", "Young, Dareke", "Grant, Charles", 
        "Meredith, Jordan", "Putnam, Will", "Rogers, Caleb", "Wagner, Dalton", 
        "Mayer, Michael", "", "Laube, Dylan", "", "Hemingway, Tonka", "Pegues, JJ", 
        "Booker IV, Thomas T", "Snowden, Charles", "Eichenberg, Tommy", "Lindenberg, Cody", 
        "Koonce, Malcolm", "Richardson, Decamerion", "", "McCollum, Tristin", 
        "Anusiem, Chigozie", "Vance, Greedy", "", ""
    ],
    "Player 3": [
        "Dorsett II, Phillip", "Shorter, Justin", "", "", "Mafi, Atonio", "", 
        "Robinson, Layden", "Miles, Joshua", "Runyon, Carter", "", "Collier, Chris", 
        "", "", "Martin, Brodric", "Ma'ae, Treven", "Jackson, Brennan", "Olubi, Segun", 
        "Davis, Jamin", "Harvey, Jahfari", "", "", "", "", "", "", ""
    ],
    "Player 4": [
        "Rice, Brenden", "", "", "", "Curtis, McClendon", "", "Tasi, Laki", "", 
        "Okwuegbunam Jr., Albert", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", ""
    ]
} 

df = pd.DataFrame(data)
csv_filename = "Raiders_depth_chart.csv"
df.to_csv(csv_filename)
